# %%
f= open("data.csv","w")
for i in range(10):
    f.write(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 f= open("data.csv","w")
#       2 for i in range(10):
# ----> 3     f.write(i)
#
# TypeError: write() argument must be str, not int
